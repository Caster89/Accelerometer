# %%
# %matplotlib inline
from recording import Position

# %%
data = Position('Data/00006.CSV',  plot = True)
# Out:
# recording.py:223: RuntimeWarning: divide by zero encountered in divide
#   err = np.sqrt(np.sum(((g[:i]-c)/g[:i])**2))

# %%
import quaternion
a = quaternion.quaternion(0,1,2,3)
